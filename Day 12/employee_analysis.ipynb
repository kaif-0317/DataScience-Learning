# %% [markdown]
# ## 8. Conclusion
#
# The employee dataset was successfully analyzed using Python and Pandas.
# The analysis identified salary statistics, employee distribution, and
# department-level information.
#
# Visualizations were used to make the results easier to understand.
# The notebook has been organized with clear headings, comments,
# formatted outputs, and readable charts for professional presentation.

# %% [markdown]
# ## 7. Business Insights
#
# Based on the analysis, the following observations can be made:
#
# 1. The dataset contains 6 employees.
# 2. The total salary paid to employees is ₹265,000.
# 3. The average employee salary is approximately ₹44,166.67.
# 4. Mike has the highest salary at ₹50,000.
# 5. John has the lowest salary at ₹35,000.
# 6. The IT department has the highest number of employees.
# 7. Salary levels vary across employees and departments.

# %%
department_counts = df["Department"].value_counts()

print(department_counts)

plt.figure(figsize=(8, 5))

department_counts.plot(kind="bar")

plt.title("Employees by Department")
plt.xlabel("Department")
plt.ylabel("Number of Employees")

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Employees by Department
#
# This analysis shows the number of employees in each department.

# %%
plt.figure(figsize=(8, 5))

plt.bar(df["Name"], df["Salary"])

plt.title("Employee Salary Comparison")
plt.xlabel("Employee")
plt.ylabel("Salary (₹)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Salary by Employee
#
# The following bar chart compares the salaries of individual employees.

# %%
# Calculate key business metrics
total_salary = df["Salary"].sum()
average_salary = df["Salary"].mean()
highest_salary = df["Salary"].max()
lowest_salary = df["Salary"].min()
total_employees = len(df)

print(f"Total Employees   : {total_employees}")
print(f"Total Salary      : ₹{total_salary:,}")
print(f"Average Salary    : ₹{average_salary:,.2f}")
print(f"Highest Salary    : ₹{highest_salary:,}")
print(f"Lowest Salary     : ₹{lowest_salary:,}")

# %% [markdown]
# ## 4. Business Analysis
#
# The following calculations help identify important business insights
# from the employee dataset.

# %%
print("Dataset Shape:", df.shape)

print("\nColumn Names:")
print(df.columns.tolist())

print("\nDataset Information:")
df.info()

# %% [markdown]
# ## 3. Dataset Overview
#
# Let's examine the structure and basic information of the dataset.

# %%
# Create the employee dataset
data = {
    "Name": ["John", "Sarah", "Mike", "Emma", "David", "Chris"],
    "Age": [25, 28, 27.33, 30, 27, 29],
    "Department": ["HR", "Finance", "IT", "Marketing", "IT", "IT"],
    "Salary": [35000, 42000, 50000, 45000, 48000, 45000]
}

df = pd.DataFrame(data)

df

# %% [markdown]
# ## 2. Employee Dataset
#
# The dataset contains employee information including name, age,
# department, and salary.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Import Required Libraries
#
# The following libraries are used for data analysis and visualization.

# %% [markdown]
# # Employee Data Analysis
#
# ## Data Cleaning, Analysis and Business Insights
#
# This notebook demonstrates data loading, cleaning, analysis,
# visualization, and business insights using Python, Pandas, and Matplotlib.
